# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', 100)

# %%
df_raw = pd.read_excel("./datasets/bikesales.xlsx")
df_clean = df_raw.copy()

# %% [markdown]
# ## 1. Reglas de limpieza

# %% [markdown]
# ### 1.1 Normalización de nombres de columnas (Log 3.1)

# %% [markdown]
# Acción:
# Normalizar nombres de columnas a estilo snake_case.

# %% [markdown]
# ### 1.2 Columnas sin valor analitico (Log 3.2)

# %% [markdown]
# Acción:
# Eliminar columnas **day**, **month**, **year**, **product_category** y **sub_category**

# %% [markdown]
# ### 1.3 Extraer atributos de product_description

# %% [markdown]
# Acción:
# La columna **product_description** contiene atributos de talla y color que conviene separar en **frame_size** y **product_color** para labores de business analytics

# %% [markdown]
# ### 1.4 Valores nulos (log 3.3)

# %% [markdown]
# ##### Nulos en age_group

# %% [markdown]
# Acción:
# Reconstruir a partir de **customer_age**

# %% [markdown]
# ##### Nulos en order_quantity

# %% [markdown]
# Acción:
# Reconstruir a partir de **unit_cost** y **cost**

# %% [markdown]
# ##### Nulos en product_description

# %% [markdown]
# Acción:
# Reconstruir a partir de **unit_cost**

# %% [markdown]
# ### 1.5 Valores duplicados (log 3.4)

# %% [markdown]
# Acción:
# Crear un identificador único para cada fila con un mismo order_id

# %% [markdown]
# ### 1.6 Problemas categóricos (log 3.5)

# %% [markdown]
# Acción:
# Normalizar valores categoricos aplicando str.strip(), str.lower(), colapso de espacios y elminización de caracteres no estándar

# %% [markdown]
# ### 1.7 valores imposibles (log 3.6)

# %% [markdown]
# #### Registros con cost = 0 y unit_cost = 0

# %% [markdown]
# Acción: inferir el valor correcto como:
#
#  **cost** = **revenue** - **profit**
#
#  **unit_cost** = **cost** /  **order quantity**

# %% [markdown]
# #### Registros con revenue = 0 y unit_price = 0

# %% [markdown]
# Acción: inferir el valor correcto como:
#
#  **revenue** = **cost** + **profit**
#
#  **unit_price** = **revenue** / **order_quantity**

# %% [markdown]
# ## Limpieza de datos

# %%
df_clean.columns = (
    df_clean.columns
    .str.strip()
    .str.lower()
    .str.replace(" ","_")
    .str.replace(r"[^0-9a-zA-Z_]+","", regex = True)
    .str.strip("_")
)
df_raw.columns = df_clean.columns

# %%
df_clean.drop("day", axis = 1, inplace = True)
df_clean.drop("month", axis = 1, inplace = True)
df_clean.drop("year", axis = 1, inplace = True)
df_clean.drop("product_category", axis = 1, inplace = True)
df_clean.drop("sub_category", axis = 1, inplace = True)
df_clean
# Out:
#     sales_order       date  customer_age             age_group  \
# 0        261695 2021-12-01            39        Adults (35-64)
# 1        261695 2021-12-01            44        Adults (35-64)
# 2        261697 2021-12-02            37        Adults (35-64)
# 3        261698 2021-12-02            31  Young Adults (25-34)
# 4        261699 2021-12-03            37        Adults (35-64)
# ..          ...        ...           ...                   ...
# 84       261778 2021-12-22            41        Adults (35-64)
# 85       261779 2021-12-23            30  Young Adults (25-34)
# 86       261780 2021-12-23            31  Young Adults (25-34)
# 87       261781 2021-12-23            35        Adults (35-64)
# 88       261782 2021-12-24            38        Adults (35-64)
#
#    customer_gender         country             state  \
# 0                F   United States        California
# 1                M  United Kingdom           England
# 2                M   United States        California
# 3                F       Australia   New South Wales
# 4                F  United  States        California
# ..             ...             ...               ...
# 84               M         Germany            Hessen
# 85               F   United States            Oregon
# 86               F          Canada  British Columbia
# 87               F   United States        California
# 88               M       Australia        Queensland
#
#           product_description  order_quantity  unit_cost  unit_price  profit  \
# 0      Mountain-200 Black, 46             4.0       1252        2295    4172
# 1     Mountain-200 Silver, 42             1.0       1266        2320    1054
# 2   Mountain-400-W Silver, 46             2.0        420         769     698
# 3   Mountain-400-W Silver, 42             1.0        420         769     349
# 4      Mountain-200 Black, 46             2.0          0        2295    2086
# ..                        ...             ...        ...         ...     ...
# 84    Mountain-200 Silver, 38             1.0       1266        2320    1054
# 85    Mountain-200 Silver, 42             1.0       1266        2320    1054
# 86     Mountain-200 Black, 42             1.0       1252        2295    1043
# 87     Mountain-500 Black, 42             1.0        295         540     245
# 88     Mountain-200 Black, 42             4.0       1252        2295    4172
#
#     cost  revenue
# 0   5008     9180
# 1   1266     2320
# 2    840     1538
# 3    420      769
# 4      0     4590
# ..   ...      ...
# 84  1266     2320
# 85  1266     2320
# 86  1252     2295
# 87   295      540
# 88  5008     9180
#
# [89 rows x 14 columns]

# %%
# Trabajaremos con las columnas originales

df_clean["frame_size"] = (
    df_raw.product_description
    .str.extract(r",\s*(\d+)$")
)

df_clean["product_color"] = (
    df_clean.product_description
    .str.extract(r"\s*([a-zA-Z]+)$")
)

df_clean["product_description"] = (
    df_clean.product_description
    .str.replace(r",\s*\d+$","", regex = True)
    .str.replace(r"\s*[a-zA-Z]+$","", regex = True)
)

# %%
df_clean
# Out:
#     sales_order       date  customer_age             age_group  \
# 0        261695 2021-12-01            39        Adults (35-64)
# 1        261695 2021-12-01            44        Adults (35-64)
# 2        261697 2021-12-02            37        Adults (35-64)
# 3        261698 2021-12-02            31  Young Adults (25-34)
# 4        261699 2021-12-03            37        Adults (35-64)
# ..          ...        ...           ...                   ...
# 84       261778 2021-12-22            41        Adults (35-64)
# 85       261779 2021-12-23            30  Young Adults (25-34)
# 86       261780 2021-12-23            31  Young Adults (25-34)
# 87       261781 2021-12-23            35        Adults (35-64)
# 88       261782 2021-12-24            38        Adults (35-64)
#
#    customer_gender         country             state product_description  \
# 0                F   United States        California        Mountain-200
# 1                M  United Kingdom           England        Mountain-200
# 2                M   United States        California      Mountain-400-W
# 3                F       Australia   New South Wales      Mountain-400-W
# 4                F  United  States        California        Mountain-200
# ..             ...             ...               ...                 ...
# 84               M         Germany            Hessen        Mountain-200
# 85               F   United States            Oregon        Mountain-200
# 86               F          Canada  British Columbia        Mountain-200
# 87               F   United States        California        Mountain-500
# 88               M       Australia        Queensland        Mountain-200
#
#     order_quantity  unit_cost  unit_price  profit  cost  revenue frame_size  \
# 0              4.0       1252        2295    4172  5008     9180         46
# 1              1.0       1266        2320    1054  1266     2320         42
# 2              2.0        420         769     698   840     1538         46
# 3              1.0        420         769     349   420      769         42
# 4              2.0          0        2295    2086     0     4590         46
# ..             ...        ...         ...     ...   ...      ...        ...
# 84             1.0       1266        2320    1054  1266     2320         38
# 85             1.0       1266        2320    1054  1266     2320         42
# 86             1.0       1252        2295    1043  1252     2295         42
# 87             1.0        295         540     245   295      540         42
# 88             4.0       1252        2295    4172  5008     9180         42
#
#    product_color
# 0          Black
# 1         Silver
# 2         Silver
# 3         Silver
# 4          Black
# ..           ...
# 84        Silver
# 85        Silver
# 86         Black
# 87         Black
# 88         Black
#
# [89 rows x 16 columns]
